# %% [markdown]
# # EDA: Visualization

# %% [markdown]
# In this lecture, we'll continue expanding on EDA, and focus on visualization.
#
# We'll talk about data correlations
#
# We'll use different types of plots to visualize data, and different libraries to do so

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %matplotlib inline
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
plt.style.use("bmh")

# %% [markdown]
# ## Importing the datasets

# %%
auto_mpg_df = pd.read_table('./data/auto-mpg/auto-mpg.data', sep="\t")
sales_df = pd.read_csv('./data/sales/sales.csv')
datasaurus_df = pd.read_table('./data/datasaurus/datasaurus.tsv')
income_df = pd.read_csv('./data/income/income.csv')
housing_df = pd.read_csv('./data/housing/housing.csv')

# %% [markdown]
# Making sure we imported the data correctly

# %%
display(auto_mpg_df.sample())
display(sales_df.sample())
display(datasaurus_df.sample())
display(income_df.sample())
display(housing_df.sample())

# %% [markdown]
# ## Visualizing the data and the relationships between the variables
# ### Histograms
# Histograms are used to visualize the distribution of a variable.

# %% [markdown]
# Ex1: For a single variable

# %%
auto_mpg_df['displacement'].hist(bins=50, figsize=(10,5))
# Out:
# <Axes: >

# %% [markdown]
# Ex2: For multiple variables

# %%
auto_mpg_df[['displacement', 'mpg']].hist(bins=50, figsize=(10,5))
plt.show()

# %% [markdown]
# Ex3: For all variables

# %%
auto_mpg_df.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# using seaborn

# %%
# using seaborn to plot histograms
sns.histplot(auto_mpg_df['displacement'], bins=50, kde=True)
plt.show()

# %% [markdown]
# ### Scatter plots
# Scatter plots are used to visualize the relationship between two variables.

# %%
# Relationship between mpg and weight
auto_mpg_df.plot(kind="scatter", x="mpg", y="weight", alpha=0.2)
plt.show()

# %%
# Relationship between horsepower and mpg and using seaborn
sns.scatterplot(data=auto_mpg_df, x="horsepower", y="mpg", alpha=0.3)
plt.show()

# %%
# Relationship between horsepower and weight and using seaborn
sns.scatterplot(data=auto_mpg_df, x="horsepower", y="weight", alpha=0.3)
plt.show()

# %% [markdown]
# What does this correlation imply? causation? correlation?

# %%
# Relationship between a group of variables
from pandas.plotting import scatter_matrix
attributes = ["mpg", "displacement", "horsepower", "weight", "cylinders"]

scatter_matrix(auto_mpg_df[attributes], figsize=(12, 8))
plt.show()

# %% [markdown]
# what does the cylinder charts mean?

# %% [markdown]
# > Show the same chart on a different dataset (using seaborn)

# %%
sns.pairplot(income_df)
plt.show()

# %% [markdown]
# ### Correlations and Heatmaps
# Correlation mean the relationship between two variables. Correlation can be positive (increase in one variable results in increase in the other variable) or negative (increase in one variable results in decrease in the other variable).
#
# A correlation matrix is a table showing correlation coefficients between variables.

# %%
# Get the correlation coefficient as a matrix
auto_corr_matrix = auto_mpg_df.corr()
auto_corr_matrix
# Out:
# /var/folders/k9/6xth_22x29gbgg2g0_q5sfv40000gq/T/ipykernel_76323/1156309416.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   auto_corr_matrix = auto_mpg_df.corr()
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775908     -0.784815   -0.777774 -0.832052
# cylinders    -0.775908   1.000000      0.931733    0.845694  0.896315
# displacement -0.784815   0.931733      1.000000    0.871745  0.909072
# horsepower   -0.777774   0.845694      0.871745    1.000000  0.867642
# weight       -0.832052   0.896315      0.909072    0.867642  1.000000
# acceleration  0.422095  -0.528078     -0.564708   -0.701634 -0.436600
# model_year    0.578596  -0.362513     -0.375414   -0.423652 -0.317588
# origin        0.564706  -0.569007     -0.605413   -0.461542 -0.585608
#
#               acceleration  model_year    origin
# mpg               0.422095    0.578596  0.564706
# cylinders        -0.528078   -0.362513 -0.569007
# displacement     -0.564708   -0.375414 -0.605413
# horsepower       -0.701634   -0.423652 -0.461542
# weight           -0.436600   -0.317588 -0.585608
# acceleration      1.000000    0.304091  0.222774
# model_year        0.304091    1.000000  0.190845
# origin            0.222774    0.190845  1.000000

# %% [markdown]
# ### Heatmaps

# %%
sns.heatmap(auto_corr_matrix, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# Using a simpler dataset, and using SeaBorn

# %%
# how are the different variables related to each other?
sns.pairplot(income_df)
plt.show()

# %%
# correlation matrix
corr_matrix = income_df.corr()
corr_matrix
# Out:
#            Education  Seniority    Income
# Education   1.000000   0.194515  0.901003
# Seniority   0.194515   1.000000  0.518288
# Income      0.901003   0.518288  1.000000

# %%
# correlation matrix heatmap
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# Should that mean we can get rid of the seniority column?

# %% [markdown]
# ### 3D scatter plot

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(projection='3d')
ax.scatter(income_df['Education'], income_df['Seniority'], income_df['Income'])
ax.set_xlabel('Education')
ax.set_ylabel('Seniority')
ax.set_zlabel('Income')
plt.show()

# %%
# using Plotly
fig = px.scatter_3d(income_df, x='Education', y='Seniority', z='Income', )
fig.show()
